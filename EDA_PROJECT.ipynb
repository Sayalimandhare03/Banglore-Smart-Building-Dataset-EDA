# %% [markdown]
# # Banglore Smart Building Dataset of Banglore City

# %% [raw]
# * Basis EDA - EDA means cleaning process
# * Handling Null/Missing Values
# * Handling Outliers
# * Handling Skewness
# * Handling Categorical Features
# * Data Normalization and Scaling
# * Feature Engineering

# %%
# Importing required libraries
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Importing warnings to ignore module warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading Dataset

# %%
BS = pd.read_csv(r"C:\Users\ōṁ\Documents\Python\building_data.csv")

# %%
BS
# Out:
#            City          Area  Building_Type  Construction_Year  \
# 0     Bangalore     Yelahanka    Residential               1989
# 1     Bangalore    Whitefield  Institutional               1980
# 2     Bangalore   Koramangala     Industrial               2006
# 3     Bangalore     Jayanagar     Commercial               1985
# 4     Bangalore    HSR Layout     Industrial               2006
# ...         ...           ...            ...                ...
# 1245  Bangalore  Malleshwaram    Residential               1985
# 1246  Bangalore     Jayanagar     Commercial               2007
# 1247  Bangalore   Koramangala     Commercial               1990
# 1248  Bangalore        Hebbal  Institutional               2021
# 1249  Bangalore     Yelahanka    Residential               2017
#
#       Number_of_Floors  Energy_Consumption_Per_SqM  Water_Usage_Per_Building  \
# 0                   12                   50.000000                477.681762
# ...

# %%
BS.head()
# Out:
#         City         Area  Building_Type  Construction_Year  Number_of_Floors  \
# 0  Bangalore    Yelahanka    Residential               1989                12
# 1  Bangalore   Whitefield  Institutional               1980                 6
# 2  Bangalore  Koramangala     Industrial               2006                10
# 3  Bangalore    Jayanagar     Commercial               1985                 1
# 4  Bangalore   HSR Layout     Industrial               2006                12
#
#    Energy_Consumption_Per_SqM  Water_Usage_Per_Building  \
# 0                   50.000000                477.681762
# 1                  225.759107                200.000000
# 2                   98.755927                200.000000
# 3                   68.470692                200.000000
# 4                   50.000000                347.093644
#
#    Waste_Recycled_Percentage  Occupancy_Rate  Indoor_Air_Quality  \
# 0                  48.417266       81.814110           13.780635
# ...

# %%
BS.tail()
# Out:
#            City          Area  Building_Type  Construction_Year  \
# 1245  Bangalore  Malleshwaram    Residential               1985
# 1246  Bangalore     Jayanagar     Commercial               2007
# 1247  Bangalore   Koramangala     Commercial               1990
# 1248  Bangalore        Hebbal  Institutional               2021
# 1249  Bangalore     Yelahanka    Residential               2017
#
#       Number_of_Floors  Energy_Consumption_Per_SqM  Water_Usage_Per_Building  \
# 1245                10                  147.613313                677.914745
# 1246                 5                   50.000000                861.042961
# 1247                 1                   50.000000               1500.000000
# 1248                 6                  250.000000               1500.000000
# 1249                 8                  143.821153               1500.000000
#
#       Waste_Recycled_Percentage  Occupancy_Rate  Indoor_Air_Quality  \
# ...

# %%
BS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   City                         1250 non-null   object
#  1   Area                         1250 non-null   object
#  2   Building_Type                1250 non-null   object
#  3   Construction_Year            1250 non-null   int64
#  4   Number_of_Floors             1250 non-null   int64
#  5   Energy_Consumption_Per_SqM   1250 non-null   float64
#  6   Water_Usage_Per_Building     1250 non-null   float64
#  7   Waste_Recycled_Percentage    1250 non-null   float64
#  8   Occupancy_Rate               1250 non-null   float64
#  9   Indoor_Air_Quality           1250 non-null   float64
#  10  Smart_Devices_Count          1250 non-null   int64
#  11  Green_Certified              1250 non-null   int64
#  12  Maintenance_Resolution_Time  1250 non-null   float64
# ...

# %%
BS.describe()
# Out:
#        Construction_Year  Number_of_Floors  Energy_Consumption_Per_SqM  \
# count        1250.000000       1250.000000                 1250.000000
# mean         1996.735200          7.118400                  108.745712
# std            15.696515          3.773456                   72.180593
# min          1970.000000          1.000000                   50.000000
# 25%          1983.000000          4.000000                   50.000000
# 50%          1996.000000          7.000000                   72.868797
# 75%          2010.000000         11.000000                  154.658612
# max          2023.000000         13.000000                  250.000000
#
#        Water_Usage_Per_Building  Waste_Recycled_Percentage  Occupancy_Rate  \
# count               1250.000000                1250.000000     1250.000000
# mean                 647.021156                  28.831580       77.285182
# std                  485.194992                  16.250126       15.093523
# ...

# %%
BS.shape
# Out:
# (1250, 19)

# %%
BS.dtypes
# Out:
# City                            object
# Area                            object
# Building_Type                   object
# Construction_Year                int64
# Number_of_Floors                 int64
# Energy_Consumption_Per_SqM     float64
# Water_Usage_Per_Building       float64
# Waste_Recycled_Percentage      float64
# Occupancy_Rate                 float64
# Indoor_Air_Quality             float64
# Smart_Devices_Count              int64
# Green_Certified                  int64
# Maintenance_Resolution_Time    float64
# Last_Inspection_Date            object
# Building_Status                 object
# Maintenance_Priority            object
# Energy_Per_SqM                 float64
# Number_of_Residents              int64
# Electricity_Bill               float64
# dtype: object

# %%
BS.columns
# Out:
# Index(['City', 'Area', 'Building_Type', 'Construction_Year',
#        'Number_of_Floors', 'Energy_Consumption_Per_SqM',
#        'Water_Usage_Per_Building', 'Waste_Recycled_Percentage',
#        'Occupancy_Rate', 'Indoor_Air_Quality', 'Smart_Devices_Count',
#        'Green_Certified', 'Maintenance_Resolution_Time',
#        'Last_Inspection_Date', 'Building_Status', 'Maintenance_Priority',
#        'Energy_Per_SqM', 'Number_of_Residents', 'Electricity_Bill'],
#       dtype='object')

# %%
BS.describe(include=['object'])
# Out:
#              City       Area Building_Type Last_Inspection_Date  \
# count        1250       1250          1250                 1250
# unique          1         11             4                  767
# top     Bangalore  Jayanagar    Industrial           03-06-2023
# freq         1250        128           327                    5
#
#        Building_Status Maintenance_Priority
# count             1250                 1250
# unique               3                    3
# top             Closed               Medium
# freq               436                  439

# %%
BS.isnull().sum()
# Out:
# City                           0
# Area                           0
# Building_Type                  0
# Construction_Year              0
# Number_of_Floors               0
# Energy_Consumption_Per_SqM     0
# Water_Usage_Per_Building       0
# Waste_Recycled_Percentage      0
# Occupancy_Rate                 0
# Indoor_Air_Quality             0
# Smart_Devices_Count            0
# Green_Certified                0
# Maintenance_Resolution_Time    0
# Last_Inspection_Date           0
# Building_Status                0
# Maintenance_Priority           0
# Energy_Per_SqM                 0
# Number_of_Residents            0
# Electricity_Bill               0
# dtype: int64

# %%
sns.boxplot(BS['Construction_Year'])
# Out:
# <Axes: ylabel='Construction_Year'>

# %%
sns.boxplot(BS['Number_of_Floors'])
# Out:
# <Axes: ylabel='Number_of_Floors'>

# %%
cat_BS = BS.select_dtypes(include=['object'])

num_BS = BS.select_dtypes(include=['float64','int64'])

# %%
cat_BS.head()
# Out:
#         City         Area  Building_Type Last_Inspection_Date  \
# 0  Bangalore    Yelahanka    Residential           25-09-2023
# 1  Bangalore   Whitefield  Institutional           18-05-2024
# 2  Bangalore  Koramangala     Industrial           28-09-2023
# 3  Bangalore    Jayanagar     Commercial           17-10-2022
# 4  Bangalore   HSR Layout     Industrial           25-04-2024
#
#      Building_Status Maintenance_Priority
# 0  Under Maintenance                 High
# 1  Under Maintenance                 High
# 2        Operational               Medium
# 3             Closed                  Low
# 4             Closed               Medium

# %%
num_BS.head()
# Out:
#    Construction_Year  Number_of_Floors  Energy_Consumption_Per_SqM  \
# 0               1989                12                   50.000000
# 1               1980                 6                  225.759107
# 2               2006                10                   98.755927
# 3               1985                 1                   68.470692
# 4               2006                12                   50.000000
#
#    Water_Usage_Per_Building  Waste_Recycled_Percentage  Occupancy_Rate  \
# 0                477.681762                  48.417266       81.814110
# 1                200.000000                  46.405516       45.109000
# 2                200.000000                  17.247585       48.526225
# 3                200.000000                  57.719480       76.335921
# 4                347.093644                  26.936862       96.511319
#
#    Indoor_Air_Quality  Smart_Devices_Count  Green_Certified  \
# 0           13.780635                    6                0
# ...

# %%
cat_BS.tail()
# Out:
#            City          Area  Building_Type Last_Inspection_Date  \
# 1245  Bangalore  Malleshwaram    Residential           20-02-2022
# 1246  Bangalore     Jayanagar     Commercial           08-11-2021
# 1247  Bangalore   Koramangala     Commercial           12-10-2022
# 1248  Bangalore        Hebbal  Institutional           13-01-2022
# 1249  Bangalore     Yelahanka    Residential           21-03-2023
#
#         Building_Status Maintenance_Priority
# 1245        Operational                  Low
# 1246             Closed                  Low
# 1247  Under Maintenance               Medium
# 1248        Operational               Medium
# 1249  Under Maintenance                  Low

# %%
num_BS.tail()
# Out:
#       Construction_Year  Number_of_Floors  Energy_Consumption_Per_SqM  \
# 1245               1985                10                  147.613313
# 1246               2007                 5                   50.000000
# 1247               1990                 1                   50.000000
# 1248               2021                 6                  250.000000
# 1249               2017                 8                  143.821153
#
#       Water_Usage_Per_Building  Waste_Recycled_Percentage  Occupancy_Rate  \
# 1245                677.914745                  29.602927       84.905237
# 1246                861.042961                  23.576263       97.506525
# 1247               1500.000000                  46.190167       94.054395
# 1248               1500.000000                  55.807260       67.780207
# 1249               1500.000000                  13.855410       77.499626
#
#       Indoor_Air_Quality  Smart_Devices_Count  Green_Certified  \
# ...

# %%
from scipy.stats import skew

# %%
for col in num_BS:
    print(col)
    print(skew(num_BS[col]))

    plt.figure()
    sns.histplot(num_BS[col], kde=True)
    plt.show()
# Out:
# Construction_Year
# 0.008484977429385764
# Number_of_Floors
# -0.06050974938254831
# Energy_Consumption_Per_SqM
# 0.9501254345939056
# Water_Usage_Per_Building
# 0.7393816199244727
# Waste_Recycled_Percentage
# 0.5285474007626764
# Occupancy_Rate
# -0.8908787427473027
# Indoor_Air_Quality
# 0.6329314034728202
# Smart_Devices_Count
# 1.0250082533565013
# Green_Certified
# 1.2330456755227066
# Maintenance_Resolution_Time
# 4.663972883985111
# Energy_Per_SqM
# 0.16063674538636563
# Number_of_Residents
# -0.06726432869319274
# Electricity_Bill
# 0.015419558640586032

# %%
sns.heatmap(num_BS.corr(),annot=True)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(6, 4))
sns.boxplot(data=BS["Energy_Consumption_Per_SqM"], ax=axes[0])
sns.violinplot(data=BS["Energy_Consumption_Per_SqM"], ax=axes[1])
# Out:
# <Axes: ylabel='Energy_Consumption_Per_SqM'>

# %%
features = ["Energy_Consumption_Per_SqM","Water_Usage_Per_Building"]
BS[features].hist(figsize=(10 , 4))
# Out:
# array([[<Axes: title={'center': 'Energy_Consumption_Per_SqM'}>,
#         <Axes: title={'center': 'Water_Usage_Per_Building'}>]],
#       dtype=object)

# %%
BS[features].describe()
# Out:
#        Energy_Consumption_Per_SqM  Water_Usage_Per_Building
# count                 1250.000000               1250.000000
# mean                   108.745712                647.021156
# std                     72.180593                485.194992
# min                     50.000000                200.000000
# 25%                     50.000000                200.000000
# 50%                     72.868797                451.638391
# 75%                    154.658612               1013.701569
# max                    250.000000               1500.000000

# %%
features = ["Occupancy_Rate","Waste_Recycled_Percentage"]
BS[features].hist(figsize=(10 , 4))
# Out:
# array([[<Axes: title={'center': 'Occupancy_Rate'}>,
#         <Axes: title={'center': 'Waste_Recycled_Percentage'}>]],
#       dtype=object)

# %%
BS[features].describe()
# Out:
#        Occupancy_Rate  Waste_Recycled_Percentage
# count     1250.000000                1250.000000
# mean        77.285182                  28.831580
# std         15.093523                  16.250126
# min         17.600798                   0.908321
# 25%         68.047227                  15.948639
# 50%         80.355416                  26.828853
# 75%         88.977348                  39.807403
# max         99.923707                  80.886835

# %%
sns.displot(BS["Maintenance_Resolution_Time"])

# %%
sns,
